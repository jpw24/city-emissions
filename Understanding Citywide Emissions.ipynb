# %% [markdown]
# # Understanding Citywide Emissions
#
# This notebook provides an end-to-end approach to emissions in cities globally.
#
# This data comes from Kaggle, and you can access the links here:
# - https://www.kaggle.com/datasets/fkosmowski/cdp-complementary-datasets
# - https://www.kaggle.com/datasets/hasibalmuzdadid/global-air-pollution-dataset
# - https://www.kaggle.com/datasets/juanmah/world-cities
# - https://www.kaggle.com/datasets/mvieira101/global-cost-of-living
#
#
# All of my visualizations are in the <i>Visualizations</i> folder of my github page.
#
# Thank you for visiting!
#
# Jimmy
